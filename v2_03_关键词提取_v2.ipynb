# %% [markdown]
# **关键词提取**
#
# > 按**栏目**分，得到每一个标题的所有分词：
# >
# > > 将每一条的留言内容、标题、回复内容合并
# > >
# > > 过滤掉非中、英文
# > >
# > > 进行分词
# > >
# > > 分词得到的内容与应用词匹配，筛选应用词中出现过的分词
# >
# > TF-IDF关键词提取：
# >
# > > 将内容按栏目合并
# > >
# > > 过滤掉非中、英文
# > >
# > > 进行分词，且与应用词匹配
# > >
# > > 计算TF-IDF，注意默认参数
# >
# > TextRank关键词提取：
# >
# > > 按记录合并留言内容、标题、回复内容
# > >
# > > 过滤掉非中、英文
# > >
# > > 进行分词，且与应用词匹配
# > >
# > > 按照标题进行TextRank计算

# %%
import os
import time
from glob import glob
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import jieba
import jieba.analyse
import jieba.posseg as pseg
from wordcloud import WordCloud
import re
import imageio
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.sans-serif'] = 'SimHei' 
plt.rcParams['axes.unicode_minus'] = False 
pd.set_option('max_rows',10000)
pd.set_option('max_columns',200)
from sklearn.feature_extraction._dict_vectorizer import DictVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from text_tools import *

# %%
df = pd.read_excel('../data/processed/员工心声明细未去重删掉前三列为空.xlsx').iloc[:,1:]
print('原始形状：',df.shape)
df = df.drop_duplicates(subset=['标题','留言内容','回复内容'])
print('去重后形状：',df.shape)
# Out:
# 原始形状： (11948, 23)
# 去重后形状： (11874, 23)

# %%
df['回复内容'].fillna('0',inplace=True)
df['sentence'] = df['标题'] + df['留言内容'] + df['回复内容']

# %% [markdown]
# ## 按栏目分词
# 将原始数据按照栏目(col)分组，每个表为这个col的所有的sentence组成的字符串
# 分别对col进行分词，并且写入字典。
# >col_words的value是每个col分词后的列表，后期可以用来分词
# >col_words_unique的value是每个col分词后且去重的列表，用来检测每个词属于哪个col

# %%
col_words = {}
col_words_unique = {}
for col,df_col in df.groupby(['栏目']):
    df_col['sentence'] = df_col['sentence'].astype('str')
    ser_col = list(df_col['sentence'])
    # 将同一个栏目的内容合并成一个字符串
    tmp = '0'.join(ser_col)
    # col_words加载
    tmp_res = cut_word(pd.Series(tmp),distinct=False)
    col_words[col] = tmp_res[0]
    # col_words_unique加载
    tmp_res_unique = cut_word(pd.Series(tmp),distinct=True)
    col_words[col] = tmp_res_unique[0]
    print('-'*5,'{}栏处理完成'.format(col),'-'*5)
print('所有栏目处理完成')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\lenovo\AppData\Local\Temp\jieba.cache
# Loading model cost 1.649 seconds.
# Prefix dict has been built successfully.
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：3.285597324371338s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：1.7045302391052246s
# ----- 三农业务栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：3.075683116912842s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：2.8610169887542725s
# ----- 个人金融栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.2734522819519043s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.32566118240356445s
# ----- 交易银行栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：1.0188822746276855s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.9494633674621582s
# ----- 人力资源栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.2655465602874756s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.31151795387268066s
# ----- 信息科技栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.5288293361663818s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.5762555599212646s
# ----- 信用卡栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.03133654594421387s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.03288745880126953s
# ----- 信用审批栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：1.3061490058898926s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：1.0804104804992676s
# ----- 公司金融栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：1.0092637538909912s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.9626827239990234s
# ----- 其他栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.09496474266052246s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.10381722450256348s
# ----- 内控合规栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.022515296936035156s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.04485321044921875s
# ----- 安全保卫栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.3011739253997803s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.21143221855163574s
# ----- 小企业金融栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.16428017616271973s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.08543539047241211s
# ----- 工会栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.8606109619140625s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.8681113719940186s
# ----- 授信管理栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：1.3050947189331055s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：1.350975513458252s
# ----- 消费信贷栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.572498083114624s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.7003567218780518s
# ----- 网络金融栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.16162323951721191s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.06758856773376465s
# ----- 财务管理栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：2.3965752124786377s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：2.2840232849121094s
# ----- 运营管理栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.0501408576965332s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.046861886978149414s
# ----- 采购管理栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.05183815956115723s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.012504100799560547s
# ----- 金融市场栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.5018904209136963s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.46938133239746094s
# ----- 门户建设栏处理完成 -----
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.07288408279418945s
# 结巴分词完成，现在进行能用词筛选
# 通过能用词筛选完成。总共用时：0.07356882095336914s
# ----- 风险管理栏处理完成 -----
# 所有栏目处理完成

# %%
# col_seq：记录每个栏目的名称
# col_cont：每个栏目分词后的结果用空格链接成字符串，col_cont记录每个栏目的字符串处理内容
col_seq = []
col_cont = []
for key in col_words.keys():
    col_seq.append(key)
    col_cont.append(' '.join(col_words[key]))

# %% [markdown]
# ## TF-IDF关键词提取

# %%
# 每个栏目所有的内容为一个文档，将所有的栏目作为数组进行tfidf处理，得到每个栏目的关键词
tfidf_res,tfidf_info = tfidf_process(col_seq,col_cont)
# Out:
# 文档名称数量和文档内容数量相等，继续进行
# tfidf处理完成

# %% [markdown]
# ## TextRank关键词提取

# %%
allow_pos = ('a'  ,'ad' ,'ag' ,'al' ,'an','d','v' ,'vd'   ,'vf'   ,'vg'   ,'vi'   ,'vl'   ,'vn'   ,'vshi' ,'vx'   ,'vyou' ,'n'    ,'ng'   ,'nl'   ,'nr'   ,'nr1'  ,'nr2'  ,'nrf'  ,'nrfg'  ,'nrj'  ,'ns'   ,'nsf'  ,'nt'   ,'nz')

# %%
# 每个栏目为一个文档，分别处理每个栏目，得到每个栏目的关键词
trk_res = textrank_process(col_seq,col_cont,allow_pos)
# Out:
# 文档名称数量和文档内容数量相等，继续进行
# TextRank处理完成

# %% [markdown]
# ## 综合TF-IDF和TextRank分析
# 匹配每个栏目中TF-IDF和TextRank的筛选出的关键词

# %%
tfidf_info
# Out:
#               三农业务         个人金融         交易银行         人力资源         信息科技  \
# count  8370.000000  8370.000000  8370.000000  8370.000000  8370.000000
# mean      0.006893     0.008149     0.004426     0.006391     0.004701
# std       0.008484     0.007285     0.009995     0.008868     0.009868
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 0%        0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.009136     0.000000     0.000000     0.000000
# 75%       0.014104     0.014309     0.000000     0.013174     0.000000
# 80%       0.015821     0.015422     0.000000     0.015470     0.013128
# 85%       0.018035     0.016785     0.017816     0.018706     0.017892
# 90%       0.019438     0.018541     0.021411     0.021943     0.021669
# 95%       0.023368     0.018541     0.027733     0.024239     0.028744
# 99%       0.026488     0.021016     0.039336     0.027475     0.036091
# 100%      0.026488     0.021016     0.049254     0.027475     0.045191
# max       0.026488     0.021016     0.049254     0.027475     0.045191
#
#                信用卡         信用审批         公司金融           其他         内控合规  \
# count  8370.000000  8370.000000  8370.000000  8370.000000  8370.000000
# mean      0.005319     0.001974     0.006633     0.007080     0.003465
# std       0.009549     0.010751     0.008688     0.008328     0.010367
# min       0.000000     0.000000     0.000000     0.000000     0.000000
#
# 13      疲于      0.026409    0.653246        动词
# 14      发芽      0.026409    0.563171        动词
# 15      留客      0.026409    0.586771        动词
# 16      珍惜      0.026409    0.592364       形容词
# 17      可悲      0.026409    0.540966       形容词
# 18     合格证      0.026409    0.634981        名词
# 19      烦索      0.026409    0.480677       形容词
# 20      繁华      0.026409    0.638590       形容词
# 21     经营者      0.026409    0.611064        名词
# 22      别墅      0.026409    0.623383        名词
# 23      调制      0.026409    0.634189        动词
# 24      误选      0.026409    0.625041        动词
# 25      详单      0.026409    0.649387       形容词
# 26      观望      0.026409    0.568573        动词
# 27    农副产品      0.026409    0.645886        名词
# 28      农垦      0.026409    0.588320        名词
# 29      农担      0.026409    0.596747        名词
# 30    农村信用      0.026409    0.595732        名词
# 31      冷库      0.026409    0.680491        名词
# 32      凶猛      0.026409    0.357761       形容词
# 33      营收      0.026409    0.507784        名词
# 34      获益      0.026409    0.580880        动词
# 35      出资      0.026409    0.567840        动词
# 36      胜诉      0.026409    0.490363        动词
# 37      肉牛      0.026409    0.584485        名词
# 38      耕地      0.026409    0.490210        名词
# 39    继续执行      0.026409    0.568885        名词
# 40      列取      0.026409    0.568992        动词
# 41      经车      0.026409    0.657661        名词
# 42      烟商      0.026409    0.485432        名词
# 43      公职      0.026409    0.563583        名词
# 44      漫漫      0.026409    0.569253       形容词
# 45      导取      0.026409    0.486809        动词
# 46      政贷      0.026409    0.693372        名词
# 47      放出      0.026409    0.647419        动词
# 48      常宁      0.026409    0.362972        名词
# 49      攻破      0.026409    0.491373        动词
# 50      干旱      0.026409    0.660112       形容词
# 51      平凡      0.026409    0.571540       形容词
# 52      收缩      0.026409    0.588500        动词
# 53      底气      0.026409    0.524212        名词
# 54      张三      0.026409    0.487153        名词
# 55      拙见      0.026409    0.495074       形容词
# 56      抵类      0.026409    0.671738        动词
# 57      急速      0.026409    0.583425        副词
# 58      惊动      0.026409    0.506310       形容词
# 59      抑郁      0.026409    0.661778       形容词
# 60     手输项      0.026409    0.367245        名词
# 61      导不      0.026409    0.607050        动词
# 62     寻乌县      0.026409    0.505841        名词
# 63      旺盛      0.026409    0.509246       形容词
# 64      备足      0.026409    0.489368        动词
# 65      地头      0.026409    0.609012        名词
# 66      坚定      0.026409    0.489470       形容词
# 67      垦区      0.026409    0.684484        名词
# 68      埋单      0.026409    0.602255        动词
# 69      没报      0.026409    0.622368        动词
# 70      增速      0.026409    0.592937        动词
# 71      没扣      0.026409    0.514460        动词
# 72      复利      0.026409    0.573577       形容词
# 73      明亮      0.026409    0.591167       形容词
# 74    正当合理      0.026409    0.673748       形容词
# 75      大户      0.026409    0.509268        名词
# 76      棉花      0.026409    0.644374        名词
# 77      枪毙      0.026409    0.493928        动词
# 78      果品      0.026409    0.509183        名词
# 79      村级      0.026409    0.574607        名词
# 80      村信      0.026409    0.669781        名词
# 81      有同      0.026409    0.582845       形容词
# 82      兵团      0.026409    0.585750        名词
# 83      所放      0.026409    0.588574        动词
# 84      起期      0.026409    0.495229        动词
# 85      预设      0.026409    0.510147        动词
# 673     算法      0.021091    0.590561        名词
# 674   功能测试      0.021091    0.573746        名词
# 675     等额      0.021091    0.633497        名词
# 676   符合标准      0.021091    0.478429        名词
# 677     病人      0.021091    0.616101        名词
# 678     疲劳      0.021091    0.618079       形容词
# 679     基地      0.021091    0.677836        名词
# 680     在押      0.021091    0.569581        动词
# 681     涉诉      0.021091    0.611632        动词
# 682    流程图      0.021091    0.409370        名词
# 683    流程化      0.021091    0.494546        名词
# 684    派出所      0.021091    0.601947        名词
# 685   地理位置      0.021091    0.571389        名词
# 686   法律效力      0.021091    0.480563        名词
# 687     法官      0.021091    0.666176        名词
# 688   基本工资      0.021091    0.563808        名词
# 689     在场      0.021091    0.634613        动词
# 690     处在      0.021091    0.587240        动词
# 691    民法典      0.021091    0.594999        名词
# 692     毫无      0.021091    0.492908        动词
# 693     母亲      0.021091    0.582021        名词
# 694   大力支持      0.021091    0.602339        名词
# 695    正常化      0.021091    0.494305        动词
# 696     正向      0.021091    0.544449        副词
# 697     止期      0.021091    0.615990        动词
# 698    大大的      0.021091    0.602567        名词
# 699     在意      0.021091    0.643181        动词
# 700     受损      0.021091    0.608054        动词
# 701     吃力      0.021091    0.567063        名词
# 702     受权      0.021091    0.486374        动词
# 703     申贷      0.021091    0.668956        动词
# 704     用处      0.021091    0.579313        名词
# 705     受阻      0.021091    0.592436        动词
# 706     用以      0.021091    0.490915        动词
# 707     甘肃      0.021091    0.564873        名词
# 708     理应      0.021091    0.565444        动词
# 709     口述      0.021091    0.588478        名词
# 710     现任      0.021091    0.504221        名词
# 711     合伙      0.021091    0.566980        名词
# 712    商品房      0.021091    0.486813        名词
# 713     犯错      0.021091    0.584521        动词
# 714     特此      0.021091    0.519472        副词
# 715    合伙人      0.021091    0.606833        名词
# 716     同名      0.021091    0.562790        名词
# 717     后退      0.021091    0.536282        动词
# 718   呼伦贝尔      0.021091    0.680903        名词
# 719   响应速度      0.021091    0.597801        名词
# 720   程度较高      0.021091    0.584581        名词

# %% [markdown]
# ### 个人金融

# %%
grjr_res = kw_merge(tfidf_res,trk_res,'个人金融',0.9,0.9,major='inner')

# %%
# grjr_res

# %% [markdown]
# ### 交易银行

# %%
jyyh_res = kw_merge(tfidf_res,trk_res,'交易银行',0.9,0.9,major='inner')

# %%
# jyyh_res

# %% [markdown]
# ### 人力资源

# %%
rlzy_res = kw_merge(tfidf_res,trk_res,'人力资源',0.9,0.9,major='inner')

# %%
# rlzy_res

# %% [markdown]
# ### 信息科技

# %%
xxkj_res = kw_merge(tfidf_res,trk_res,'信息科技',0.9,0.9,major='inner')

# %%
# xxkj_res

# %% [markdown]
# ### 信用卡

# %%
credit_card_res = kw_merge(tfidf_res,trk_res,'信用卡',0.9,0.9,major='inner')

# %%
# credit_card_res

# %% [markdown]
# ### 信用审批

# %%
xysp_res = kw_merge(tfidf_res,trk_res,'信用审批',0.98,0.9,major='inner')

# %%
# xysp_res

# %% [markdown]
# ### 公司金融

# %%
gsjr_res = kw_merge(tfidf_res,trk_res,'公司金融',0.98,0.9,major='inner')

# %%
# gsjr_res

# %% [markdown]
# ### 其他

# %%
others_res = kw_merge(tfidf_res,trk_res,'其他',0.98,0.9,major='inner')

# %%
# others_res

# %% [markdown]
# ### 内控合规

# %%
nkhg_res = kw_merge(tfidf_res,trk_res,'其他',0.98,0.9,major='inner')

# %%
# nkhg_res

# %% [markdown]
# ### 安全保卫

# %%
aqbw_res = kw_merge(tfidf_res,trk_res,'其他',0.98,0.9,major='inner')

# %%
# aqbw_res

# %% [markdown]
# ### 小企业金融

# %%
xqyjr_res = kw_merge(tfidf_res,trk_res,'安全保卫',0.9,0.9,major='inner')

# %%
# xqyjr_res

# %% [markdown]
# ### 工会

# %%
labor_union_res = kw_merge(tfidf_res,trk_res,'工会',0.9,0.9,major='inner')

# %%
# labor_union_res

# %% [markdown]
# ### 授信管理

# %%
credit_mgm_res = kw_merge(tfidf_res,trk_res,'授信管理',0.9,0.9,major='inner')

# %%
# credit_mgm_res

# %% [markdown]
# ### 消费信贷

# %%
xfxd_res = kw_merge(tfidf_res,trk_res,'授信管理',0.8,0.9,major='inner')

# %%
# xfxd_res

# %% [markdown]
# ### 网络金融

# %%
network_finance_res = kw_merge(tfidf_res,trk_res,'网络金融',0.8,0.9,major='inner')

# %%
# network_finance_res

# %% [markdown]
# ### 财务管理

# %%
financeal_mgm_res = kw_merge(tfidf_res,trk_res,'财务管理',0.96,0.9,major='inner')

# %%
# financeal_mgm_res

# %% [markdown]
# ### 运营管理

# %%
operation_mgm_res = kw_merge(tfidf_res,trk_res,'运营管理',0.6,0.9,major='inner')

# %%
# operation_mgm_res

# %% [markdown]
# ### 采购管理

# %%
purchase_res = kw_merge(tfidf_res,trk_res,'采购管理',0.98,0.9,major='inner')

# %%
# purchase_res

# %% [markdown]
# ### 金融市场

# %%
financial_mkt = kw_merge(tfidf_res,trk_res,'金融市场',0.98,0.9,major='inner')

# %%
# financial_mkt

# %% [markdown]
# ### 门户建设

# %%
mhjs_res = kw_merge(tfidf_res,trk_res,'门户建设',0.9,0.9,major='inner')

# %%
# mhjs_res

# %% [markdown]
# ### 风险管理

# %%
risk_mgm_res = kw_merge(tfidf_res,trk_res,'风险管理',0.96,0.9,major='inner')

# %%
risk_mgm_res.head()
# Out:
#   word  tfidf_weight  ttk_weight word_flag
# 0   揭示      0.066815    0.717792        动词
# 1   法务      0.066815    0.610323        名词
# 2   受害      0.066815    0.628186        动词
# 3   货车      0.066815    0.719579        名词
# 4   作风      0.066815    0.711341        名词

# %% [markdown]
# ### 全部写入excel

# %%
wrt1 = pd.ExcelWriter('../result/v2/按栏目抽取关键词结果_v1.xlsx')
wrt2 = pd.ExcelWriter('../result/v2/按栏目抽取关键词结果_v2.xlsx')
for col in col_seq:
    tb1 = kw_merge(tfidf_res,trk_res,col,0.9,0.9,major='inner')
    tb1.to_excel(wrt1,sheet_name=col,index=False)
    tb2 = kw_concat(tfidf_res,trk_res,col)
    tb2.to_excel(wrt2,sheet_name=col,index=False)
wrt1.save()
wrt2.save()
